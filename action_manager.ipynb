# %%
import json
import os

# %%
class SF6ActionManagerAsync:
    """
    資料驅動的非阻塞動作管理員。
    透過讀取外部 JSON 檔案來獲取招式幀數，輕鬆應對遊戲版本更新。
    """
    def __init__(self, config_file="sf6_moves.json"):
        self.frames_per_step = 4 
        self.cooldown_frames = 0
        self.config_file = config_file
        
        # 啟動時自動載入外部招式設定檔
        self.move_list = self._load_moves()

    def _load_moves(self):
        """讀取 JSON 設定檔。如果檔案不存在，會給出清楚的錯誤提示。"""
        if not os.path.exists(self.config_file):
            raise FileNotFoundError(f"❌ 找不到招式設定檔 {self.config_file}！請確認檔案是否存在。")
            
        with open(self.config_file, 'r', encoding='utf-8') as f:
            # 將 JSON 內容載入為 Python 字典
            # 注意：JSON 的 key 會是字串 (例如 "1")，我們需要轉回整數 (1) 方便 AI 使用
            raw_data = json.load(f)
            parsed_moves = {}
            for key, value in raw_data.items():
                parsed_moves[int(key)] = value
                
        print(f"✅ 成功載入 {len(parsed_moves)} 個招式設定！")
        return parsed_moves

    def step(self, action_id):
        """執行 AI 指令並管理冷卻時間"""
        action_executed = False
        
        if self.cooldown_frames <= 0:
            # 取得招式，預設為待機 (0)
            move = self.move_list.get(action_id, self.move_list[0])
            
            if action_id != 0:
                print(f"💥 [出招] {move['name']} | 消耗幀數: {move['frames']} 幀")
                self._press_keys(move['keys'])
            
            self.cooldown_frames = move['frames']
            action_executed = True
        
        # 推進時間
        self.cooldown_frames -= self.frames_per_step
        return action_executed

    def _press_keys(self, keys):
        """內部函式：未來串接真實鍵盤 API"""
        if not keys:
            return
        print(f"   ⌨️ [模擬鍵盤] 送出按鍵: {keys}")

# %% [markdown]
# ### 測試程式碼

# %%
if __name__ == "__main__":
    # 確保你有先建立好 sf6_moves.json 檔案在同一個資料夾下！
    manager = SF6ActionManagerAsync("sf6_moves.json")
    manager.step(3) # 測試波動拳
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1191/728829443.py in <cell line: 0>()
#       1 if __name__ == "__main__":
#       2     # 確保你有先建立好 sf6_moves.json 檔案在同一個資料夾下！
# ----> 3     manager = SF6ActionManagerAsync("sf6_moves.json")
#       4     manager.step(3) # 測試波動拳
#
# /tmp/ipykernel_1191/355786698.py in __init__(self, config_file)
#      10
#      11         # 啟動時自動載入外部招式設定檔
# ---> 12         self.move_list = self._load_moves()
#      13
#      14     def _load_moves(self):
#
# /tmp/ipykernel_1191/355786698.py in _load_moves(self)
#      15         """讀取 JSON 設定檔。如果檔案不存在，會給出清楚的錯誤提示。"""
#      16         if not os.path.exists(self.config_file):
# ---> 17             raise FileNotFoundError(f"❌ 找不到招式設定檔 {self.config_file}！請確認檔案是否存在。")
#      18
#      19         with open(self.config_file, 'r', encoding='utf-8') as f:
#
# FileNotFoundError: ❌ 找不到招式設定檔 sf6_moves.json！請確認檔案是否存在。

# %%
pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (2.4.3)
# Requirement already satisfied: packaging in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (26.0)
# Requirement already satisfied: pillow in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (12.1.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (7.34.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (82.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from tensorboard) (3.1.6)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
